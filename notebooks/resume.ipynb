# %% [markdown]
# ---
# title: "Resume - Michael James Schock"
# format: html
# ---
#
# # Michael James Schock
#
# **Email:** m@mjschock.com
# **GitHub:** [mjschock](https://github.com/mjschock)
# **LinkedIn:** [in/mjschock](https://www.linkedin.com/in/mjschock)
# **Phone:** +1 925 878 5408
# **Web:** [mjschock.com](https://mjschock.com)
#
# ---
#
# ## Professional Experience
#
# ### Software Engineer (AI/ML Platform)
# - **Company:** Phaidra, Seattle, WA (Remote)
# - **Dates:** Oct. 2022 - Jan. 2024
# - **Responsibilities:**
#   - Spearheaded orchestration and automation of AI agent training into an MLOps pipeline using Prefect and Kubernetes.
#   - Prototyped an MVP for scalable training runs using Prefect-Ray integration.
#   - Modernized developer experience using Tilt for Kubernetes.
# - **Technologies:** Cloud SQL for PostgreSQL, Docker, GCP, GKE, gRPC, Prefect, Python, PyTorch, Ray, SkyPilot, Tilt
#
# ### Teaching Assistant
# - **Institution:** Georgia Institute of Technology, Atlanta, GA (Remote)
# - **Dates:** Aug. 2022 - Dec. 2022
# - **Course:** CS 7639: Cyber-Physical Systems Design & Analysis
#
# ### Machine Learning Engineer
# - **Company:** Greyscale AI, San Carlos, CA
# - **Dates:** Oct. 2021 - Jul. 2022
# - **Responsibilities:**
#   - Developed a data engineering pipeline for image processing and labeling.
#   - Constructed a data modeling pipeline with PyTorch Faster R-CNN for object detection and segmentation.
# - **Technologies:** Albumentations, Amazon SageMaker, Docker, DVC, FiftyOne, Kedro, Python, PyTorch, TorchServe, etc.
#
# (Repeat this structure for other roles listed.)
#
# ---
#
# ## Education
#
# ### Master of Science in Computer Science
# - **Institution:** Georgia Institute of Technology, Atlanta, GA
# - **Dates:** Jan. 2018 - May 2025 (Less-than-Part-Time; Remote)
# - **Specialization:** Computational Perception and Robotics
#
# ### Bachelor of Arts in Physics
# - **Institution:** University of California, Berkeley, CA
#
# ---
#
# ## Coursework & Certifications
#
# | Course/Certification                            | Institution                          | Date       |
# |-------------------------------------------------|--------------------------------------|------------|
# | CS 7650: Natural Language Processing            | Georgia Tech                         | Fall 2024  |
# | Generative AI Nanodegree                        | Udacity                              | May 2024   |
# | Prefect Associate Certification                 | Prefect                              | Apr. 2023  |
# | CS 7643: Deep Learning                          | Georgia Tech                         | Fall 2022  |
#
# (Add more as needed from the resume.)
#
# ---
#
# ## Skills
#
# - Accelerate, Agent Protocol, AutoGen, AutoGPT, bitsandbytes, Computer Vision, ControlFlow, DataDreamer, Datasets, Diffusers, Evaluate, Function/Tool Calling, JavaScript/TypeScript, LangChain, LangGraph, llama.cpp, LlamaIndex, Marvin, Multimodal LLM/VLMs, NumPy, OpenAI, PEFT, pandas, PostgreSQL, Prefect, Python, PyTorch, Ray, Reflex, scikit-learn, SkyPilot, SQL, Swarms, Tokenizers, timm, Transformers, TRL, etc.
